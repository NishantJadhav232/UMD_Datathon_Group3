# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob
import shutil
import os

# %%
metadata_df = pd.read_csv("C:/Users/abhij/Downloads/metadata.csv")

# %%
metadata_df.head(5)
# Out:
#    Record ID                                          File Name Assignment ID  \
# 0  207431327         HearstTransportation_CAMP_MontrealTeam.png      CPR6931p
# 1  207431332  HearstTransportation_MicrosoftTeams_ZoomMeetin...      CPR6931p
# 2  207431348   HearstTransportation_BlackBook_LauraWehunt_1.png      CPR6931p
# 3  207431356   HearstTransportation_BlackBook_LauraWehunt_2.png      CPR6931p
# 4  207432753                   HearstMagazines_CDS_Employee.png      CPR6931p
#
#   Year                                             Person  \
# 0  NaN                                       Unidentified
# 1  NaN  Unidentified,Don Dickson,Danya Bynoe,Varun Kum...
# 2  NaN                                       Laura Wehunt
# 3  NaN                                       Laura Wehunt
# 4  NaN                                     Bryan Phillips
#
#                                             Keywords Creators Date
# 0  People @ Work,Hearst transportation,Transporta...      NaN  NaN
# 1  People @ Work,Hearst transportation,Transporta...      NaN  NaN
# 2  People @ Work,Hearst transportation,Headshots,...      NaN  NaN
# 3  People @ Work,Hearst transportation,Headshots,...      NaN  NaN
# 4  People @ Work,CDS,Hearst Magazines,Hearst maga...      NaN  NaN

# %%
metadata_df.groupby(by = ['Keywords']).agg('count').sort_values(by = ['Record ID'], ascending=False).head(30)
# Out:
#                                                     Record ID  File Name  \
# Keywords
# People @ Work,Homecoming,2013,Events,44th Floor...        443        443
# People @ Work,2018,Events,Friday,Texas,Texas 20...        258        258
# Archdiocese of New York,Corporate,Al Smith Dinn...        230        230
# People @ Work,Spotlight 2016,Awards,Hearst Maga...        140        140
# People @ Work,Frank A. Bennack,Frank Bennack,Ev...        127        127
# People @ Work,2018,Thursday,Events,Texas,Texas ...        114        114
# People @ Work,Tower Gala,Events,Hearst Tower              111        111
# People @ Work,2019,Events,Friday,Texas,Texas 2019          98         98
# People @ Work,Texas 2016,2016,Friday,Events,Texas          97         97
# People @ Work,Texas 2017,2017,Events,Friday,Texas          96         96
# Scenery,Hearst Real Estate,2021,Outdoors,San Si...         94         94
# People @ Work,Culture Shifting Weekend,Culture ...         90         90
# People @ Work,2019,Leave Something on the Table...         89         89
# 44th Floor,Events,Hearst Ventures,Ventures,Ken ...         86         86
# People @ Work,2019,Thursday,Events,Texas,Texas ...         76         76
# Hearst Real Estate,2021,Outdoors,San Simeon,Hor...         73         73
# People @ Work,2019,Awards,Hearst Magazines,Even...         72         72
# Cooking,Jack Ranch,Hearst Real Estate,2021,Hear...         68         68
# People @ Work,Texas 2016,2016,Thursday,Events,T...         66         66
# People @ Work,Texas 2016,Alison Krauss,2016,Fri...         65         65
# People @ Work,2018,Awards,Hearst Magazines,Even...         64         64
# People @ Work,2017,Awards,Hearst Magazines,Even...         62         62
# People @ Work,2018,Frank A. Bennack,Thursday,Fr...         61         61
# People @ Work,Editorial Excellence,Hearst Magaz...         60         60
# Frank Bennack,FAB,Homecoming,44th Floor,People ...         60         60
# People @ Work,Owl's Nest,Event,44th Floor                  59         59
# People @ Work,Texas 2017,2017,Thursday,Events,T...         58         58
# People @ Work,Editorial Excellence,2018,Hearst ...         56         56
# People @ Work,Texas 2017,2017,Frank A. Bennack,...         55         55
# Hearst.com,Headshots,1276x960,Portraits,HearstL...         54         54
#
#                                                     Assignment ID  Year  \
# Keywords
# People @ Work,Homecoming,2013,Events,44th Floor...            443   443
# People @ Work,2018,Events,Friday,Texas,Texas 20...            258   258
# Archdiocese of New York,Corporate,Al Smith Dinn...              0   230
# People @ Work,Spotlight 2016,Awards,Hearst Maga...              0   140
# People @ Work,Frank A. Bennack,Frank Bennack,Ev...            127   127
# People @ Work,2018,Thursday,Events,Texas,Texas ...            114   114
# People @ Work,Tower Gala,Events,Hearst Tower                  111   111
# People @ Work,2019,Events,Friday,Texas,Texas 2019              98    98
# People @ Work,Texas 2016,2016,Friday,Events,Texas              97    97
# People @ Work,Texas 2017,2017,Events,Friday,Texas              96    96
# Scenery,Hearst Real Estate,2021,Outdoors,San Si...             94    94
# People @ Work,Culture Shifting Weekend,Culture ...             89    90
# People @ Work,2019,Leave Something on the Table...              0    89
# 44th Floor,Events,Hearst Ventures,Ventures,Ken ...              0    86
# People @ Work,2019,Thursday,Events,Texas,Texas ...             76    76
# Hearst Real Estate,2021,Outdoors,San Simeon,Hor...             73    73
# People @ Work,2019,Awards,Hearst Magazines,Even...              0    72
# Cooking,Jack Ranch,Hearst Real Estate,2021,Hear...             68    68
# People @ Work,Texas 2016,2016,Thursday,Events,T...             66    66
# People @ Work,Texas 2016,Alison Krauss,2016,Fri...             65    65
# People @ Work,2018,Awards,Hearst Magazines,Even...              0    64
# People @ Work,2017,Awards,Hearst Magazines,Even...             62    62
# People @ Work,2018,Frank A. Bennack,Thursday,Fr...             61    61
# People @ Work,Editorial Excellence,Hearst Magaz...             60    60
# Frank Bennack,FAB,Homecoming,44th Floor,People ...             60    60
# People @ Work,Owl's Nest,Event,44th Floor                      59    59
# People @ Work,Texas 2017,2017,Thursday,Events,T...             58    58
# People @ Work,Editorial Excellence,2018,Hearst ...             56    56
# People @ Work,Texas 2017,2017,Frank A. Bennack,...             55    55
# Hearst.com,Headshots,1276x960,Portraits,HearstL...              2     2
#
#                                                     Person  Creators  Date
# Keywords
# People @ Work,Homecoming,2013,Events,44th Floor...     416         0     0
# People @ Work,2018,Events,Friday,Texas,Texas 20...     186       162     0
# Archdiocese of New York,Corporate,Al Smith Dinn...     230       230     0
# People @ Work,Spotlight 2016,Awards,Hearst Maga...     129         1     0
# People @ Work,Frank A. Bennack,Frank Bennack,Ev...     127        68     0
# People @ Work,2018,Thursday,Events,Texas,Texas ...     109        80     0
# People @ Work,Tower Gala,Events,Hearst Tower           105         0     0
# People @ Work,2019,Events,Friday,Texas,Texas 2019       91        98     0
# People @ Work,Texas 2016,2016,Friday,Events,Texas       42        97     0
# People @ Work,Texas 2017,2017,Events,Friday,Texas       69        96     0
# Scenery,Hearst Real Estate,2021,Outdoors,San Si...       0        72     0
# People @ Work,Culture Shifting Weekend,Culture ...      71        89     0
# People @ Work,2019,Leave Something on the Table...      89         0     0
# 44th Floor,Events,Hearst Ventures,Ventures,Ken ...      86         0     0
# People @ Work,2019,Thursday,Events,Texas,Texas ...      73        76     0
# Hearst Real Estate,2021,Outdoors,San Simeon,Hor...       0        69     0
# People @ Work,2019,Awards,Hearst Magazines,Even...      61        72     0
# Cooking,Jack Ranch,Hearst Real Estate,2021,Hear...      36         0     0
# People @ Work,Texas 2016,2016,Thursday,Events,T...      62        66     0
# People @ Work,Texas 2016,Alison Krauss,2016,Fri...      65        65     0
# People @ Work,2018,Awards,Hearst Magazines,Even...      52         1     0
# People @ Work,2017,Awards,Hearst Magazines,Even...      52        62     0
# People @ Work,2018,Frank A. Bennack,Thursday,Fr...      61        38     0
# People @ Work,Editorial Excellence,Hearst Magaz...      47        60     0
# Frank Bennack,FAB,Homecoming,44th Floor,People ...      60         0     0
# People @ Work,Owl's Nest,Event,44th Floor               50        59     0
# People @ Work,Texas 2017,2017,Thursday,Events,T...      52        28     0
# People @ Work,Editorial Excellence,2018,Hearst ...      55         0     0
# People @ Work,Texas 2017,2017,Frank A. Bennack,...      55        46     0
# Hearst.com,Headshots,1276x960,Portraits,HearstL...      54         0     0

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# #### Split on comma and find individual keywords

# %%
clean_df = metadata_df.copy()

# %%
clean_df = clean_df.join(clean_df['Keywords'].str.get_dummies(','))

# %%
tag_df = pd.DataFrame(clean_df.iloc[:,7:].sum(axis = 0), columns = ['Count']).sort_values(by = ['Count'], ascending = False)

# %%
tag_df['Tag_Name'] = tag_df.index
tag_df.reset_index(drop = True, inplace = True)

# %%
### Further steps
tag_df['Count_tag_appears'] = tag_df['Count']
tag_df = tag_df.iloc[:,1:]

# %%
# Creating five broad categories
time_list = ['Friday','Thursday','2019','2018','2016','2021','2017','2013']
tag_df.head
# Out:
# <bound method NDFrame.head of               Tag_Name  Count_tag_appears
# 0        People @ Work               7058
# 1               Events               6483
# 2           44th Floor               2993
# 3                Texas               2090
# 4     Hearst Magazines               1611
# ...                ...                ...
# 1446   Joanne Alfarone                  1
# 1447      John Francis                  1
# 1448           Johnson                  1
# 1449   Jonathan Becker                  1
# 1450         Portraits                  1
#
# [1451 rows x 2 columns]>

# %%
tag_df[tag_df['Count_tag_appears']>100].count()
# Out:
# Tag_Name             116
# Count_tag_appears    116
# dtype: int64

# %% [markdown]
# #### Finding A Subset of Tags
# * There are 116 tags that have a count of atleast 100 in the dataset
# *Find all tags that have a count of atleast 100. Set this as an assorted list of tags
# *Check in clean_df the count of images where any one tag appears which is in the assorted list of tags
# *Remove year of picture From this tag list.
# *Ultimately reduce tags created as dummy features in original dataset to reduce dimensionality

# %%
tag_list = list(tag_df[tag_df['Count_tag_appears']>140]['Tag_Name'])

# %%
tag_list
# Out:
# ['People @ Work',
#  'Events',
#  '44th Floor',
#  'Texas',
#  'Hearst Magazines',
#  'Magazines',
#  'FAB',
#  'Frank Bennack',
#  '2019',
#  'Frank A. Bennack',
#  '2021',
#  '2016',
#  '2018',
#  'Hearst Tower',
#  'Friday',
#  'Thursday',
#  '2013',
#  'The Long Gray Line',
#  'Homecoming',
#  'Retreat',
#  'Texas 2018',
#  'Corporate',
#  'Headshots',
#  'Portraits',
#  '2017',
#  'SRS',
#  'Spotlight',
#  'Steve Swartz',
#  'Steven R. Swartz',
#  'Awards',
#  'Annual',
#  'Hearst magazines',
#  'Executives',
#  'Alfred E. Smith Memorial Foundation',
#  'Al Smith Dinner',
#  'Archdiocese of New York',
#  'Charities',
#  'Alfred E. Smith Memorial Foundation Dinner',
#  'Al Smith Dinner 2021',
#  'Catholic charities',
#  'Dinners',
#  'Texas 2016',
#  'Editorial Excellence',
#  'magazines',
#  'Texas 2017',
#  'Gil Maurer',
#  'GCM',
#  'Texas 2019',
#  'Masterclass',
#  'Gilbert C. Maurer',
#  'Annual Review',
#  'Leave Something on the Table',
#  'Spotlight 2016',
#  'Tower Gala',
#  'Photography',
#  'Hearst Real Estate',
#  'Real Estate',
#  'Tower',
#  'Tower Week',
#  'Tower Tuesdays',
#  'Joseph Urban Theater',
#  '135',
#  'Hearst Ranch',
#  'Employee Image',
#  'Ranch',
#  'FAB Book Party',
#  'Cattle',
#  'Exhibitions',
#  'Alexey Brodovitch Gallery',
#  'Career Site',
#  'Event',
#  'Annual 2019',
#  'Hearst.com',
#  'Editorial Excellence 2016',
#  'Mark Lake Bennack',
#  'Mary Lake Bennack',
#  'Michael Clinton',
#  'MAC',
#  'Michael A. Clinton',
#  'Content With Purpose',
#  'San Simeon',
#  'Outdoors',
#  'Troy Young',
#  '2014',
#  'Ventures',
#  'Hearst Ventures',
#  'HearstLab',
#  'Kate Lewis',
#  'David Carey',
#  'Colin Powell',
#  'Norman Foster',
#  'Culture Shift Labs',
#  'Hearst Health',
#  'Gathering',
#  'Horseback Riding',
#  'Ellen Levine']

# %%
#Count of images that can be excluded cannot be more than 0.5% of the dataset size. 0.5% of 9300 images roughly is 46.5. On Trial and Error a cutoff of 140 tags is found.
clean_df[(clean_df[tag_list].any(axis = 1))==False]
# Out:
#       Record ID                                          File Name  \
# 54    207993765                    CPR7566_HTV_2020_YearEnder1.png
# 55    207993767                    CPR7566_HTV_2020_YearEnder6.png
# 56    207993773                    CPR7566_HTV_2020_YearEnder5.png
# 57    207993776       CPR7566_HoustonChron_TogetherWeAreStrong.png
# 58    207993778                    CPR7566_HTV_2020_YearEnder7.png
# 59    207993781      CPR7566_WPBF_ProjectCommUNITY_DayOfGiving.png
# 60    207993784                    CPR7566_HTV_2020_YearEnder2.png
# 61    207993797                    CPR7566_HTV_2020_YearEnder3.png
# 62    207993798          CPR7566_WWVTM_HurricaneLaura_Met@Desk.png
# 63    207993803                    CPR7566_HTV_2020_YearEnder4.png
# 66    208015824  CPR7560i_BHM_Article Image_V4_1276x960_Tommy_2...
# 1254  207993766    CPR7566_WDSU_HurricaneLaura_TrackingKweilyn.jpg
# 1255  207993768         CPR7566_WCVB_CelebrityMashupFundraiser.jpg
# 1256  207993769                  CPR7566_WYFF_HurricaneIsaias2.jpg
# 1257  207993770   CPR7566_KSBW_ProjectCommUNITY_JarrettSuccess.jpg
# 1258  207993771      CPR7566_KCCI_Derecho_SpecialRelief_Stacey.jpg
# 1259  207993772           CPR7566_WVTM_HurricaneLaura_Reporter.JPG
# 1260  207993774                  CPR7566_KCRA_Wildfires_Brian.jpeg
# 1261  207993777                   CPR7566_KSBW_Wildfires_Alani.jpg
# 1262  207993779  CPR7566_KCRA_ProjectCommUNITY_Foodbank_Anchors...
# 1263  207993780           CPR7566_WDSU_HurricaneLaura_Telethon.jpg
# 1264  207993783  CPR7566_WTAE_ProjectCommUNITY_DayOfGiving_Chec...
# 1265  207993785            CPR7566_KCCI_Derecho_TotalDonations.jpg
# 1266  207993786  CPR7566_WTAE_ProjectCommUNITY_DayOfGiving_Mult...
# 1267  207993788             CPR7566_KCCI_Derecho_DamagedHouse.jpeg
# 1268  207993789                  CPR7566_KCRA_Wildfires_Vicki.jpeg
# 1269  207993792             CPR7566_KCRA_Wildfires_VickiSmoke.jpeg
# 1270  207993796   CPR7566_WDSU_HurricaneLaura_TrackingMargaret.jpg
# 1271  207993799                  CPR7566_WYFF_HurricaneIsaias1.jpg
# 1272  207993801                 CPR7566_KSBW_Wildfires_Caitlin.jpg
# 1273  207993802         CPR7566_KCRA_Wildfires_FundraiseTally.jpeg
# 1490  208032792  CPR7603_Matter of Fact Listening Tour March_RI...
# 1491  208032793  CPR7603_Matter of Fact Listening Tour March_RI...
# 1561  208702302                         ana_occhiuzzi_1276x960.jpg
# 1562  208702347                              CPR6479B_Katie Hu.jpg
# 8133  207386216                        0840_JM2_6419_USSYP2019.jpg
# 8134  207386217                        0842_JM2_6423_USSYP2019.jpg
# 8135  207386218                        0815_JM1_9779_USSYP2019.jpg
# 8138  207386221                        0808_EL2_6745_USSYP2019.jpg
# 8157  207386243      368_National_Gallery_Gala_USSYP2012_Day06.jpg
# 8171  207386267  1_6351624608504597893245215_25_HCPF_092813_pm_...
# 8173  207386269  0_63516204568277625016445215_28_HCPF_092813_pm...
# 8177  207386274                                   AnissaBalson.jpg
# 8180  207386892                         HEAR1_20120918_PMC_194.jpg
# 8181  207386893  Austin+Hearst+2nd+Annual+Save+Children+Illumin...
#
#      Assignment ID        Year  \
# 54         CPR7566         NaN
# 55         CPR7566         NaN
# 56         CPR7566         NaN
# 57         CPR7566         NaN
# 58         CPR7566         NaN
# 59         CPR7566         NaN
# 60         CPR7566         NaN
# 61         CPR7566         NaN
# 62         CPR7566         NaN
# 63         CPR7566         NaN
# 66         CPR7560  2021-02-26
# 1254       CPR7566         NaN
# 1255       CPR7566         NaN
# 1256       CPR7566         NaN
# 1257       CPR7566         NaN
# 1258       CPR7566         NaN
# 1259       CPR7566         NaN
# 1260       CPR7566         NaN
# 1261       CPR7566         NaN
# 1262       CPR7566         NaN
# 1263       CPR7566         NaN
# 1264       CPR7566         NaN
# 1265       CPR7566         NaN
# 1266       CPR7566         NaN
# 1267       CPR7566         NaN
# 1268       CPR7566         NaN
# 1269       CPR7566         NaN
# 1270       CPR7566         NaN
# 1271       CPR7566         NaN
# 1272       CPR7566         NaN
# 1273       CPR7566         NaN
# 1490       CPR7603  2021-03-19
# 1491       CPR7603  2021-03-19
# 1561           NaN  2021-06-29
# 1562      CPR6479B  2021-08-11
# 8133           NaN  2019-01-01
# 8134           NaN  2019-01-01
# 8135           NaN  2019-01-01
# 8138           NaN  2019-01-01
# 8157           NaN  2012-03-08
# 8171           NaN  2013-01-01
# 8173           NaN  2013-01-01
# 8177           NaN         NaN
# 8180           NaN         NaN
# 8181           NaN         NaN
#
#                                               Person  \
# 54                                               NaN
# 55                                 Michael Armstrong
# 56                                      Unidentified
# 57                                               NaN
# 58                                               NaN
# 59                                      Unidentified
# 60                                               NaN
# 61                                      Unidentified
# 62                                      Unidentified
# 63                                               NaN
# 66                      Tommy Atkins,Tommy J. Atkins
# 1254                                  Kweilyn Murphy
# 1255          David Muir,Martha Raddatz,Unidentified
# 1256                                    Unidentified
# 1257                                    Unidentified
# 1258                                    Unidentified
# 1259                                    Unidentified
# 1260                                    Unidentified
# 1261                                    Unidentified
# 1262                                    Unidentified
# 1263                                             NaN
# 1264                                    Unidentified
# 1265                                      Alyx Sacks
# 1266                                    Unidentified
# 1267                                             NaN
# 1268                                  Vicki Gonzalez
# 1269                                  Vicki Gonzalez
# 1270                                    Unidentified
# 1271                                    Unidentified
# 1272                                    Unidentified
# 1273                                             NaN
# 1490                                 Soledad O'Brien
# 1491                                 Soledad O'Brien
# 1561                                   Ana Occhiuzzi
# 1562                                        Katie Hu
# 8133                           William R. Hearst III
# 8134                           William R. Hearst III
# 8135                           William R. Hearst III
# 8138                           William R. Hearst III
# 8157                            George R. Hearst III
# 8171                                   Samia Staehle
# 8173                                   Samia Staehle
# 8177                                   Anissa Balson
# 8180  Austin Hearst,Gabriella Perezutti,Ralph Lauren
# 8181               Austin Hearst,Gabriella Perezutti
#
#                                                Keywords  \
# 54    Hearst Gives Back,Hearst Television,2020,Year ...
# 55    Hearst Gives Back,Hearst Television,Year Ender...
# 56    Year Ender Video,Hearst Television,Wildfires,N...
# 57    Hearst Gives Back,Hearst Newspapers,Natural Di...
# 58    Hearst Gives Back,Hearst Television,2020,Year ...
# 59    Hearst Gives Back,Hearst Television,WPBF,Proje...
# 60    Hearst Gives Back,Hearst Television,2020,Year ...
# 61    Hearst Gives Back,Hearst Television,2020,Year ...
# 62    Hearst Gives Back,Hearst Television,WVTM,Natur...
# 63    App,Year Ender Video,Hearst Television,Wildfir...
# 66                              BHM,Black History Month
# 1254  Hearst Gives Back,Hearst Television,WDSU,Natur...
# 1255  Hearst Gives Back,Hearst Television,Project Co...
# 1256  Hearst Television,Natural Disasters,Weathermen...
# 1257  Hearst Gives Back,Hearst Television,Project Co...
# 1258  Hearst Gives Back,Hearst Television,KCCI,Natur...
# 1259  Hearst Gives Back,Hearst Television,WVTM,Natur...
# 1260  Hearst Television,Wildfires,Natural Disaster,K...
# 1261  Hearst Gives Back,Hearst Television,KSBW,Natur...
# 1262  Food Drives,Anchors,Reporters,Hearst Televisio...
# 1263  Hearst Gives Back,Hearst Television,WDSU,Day o...
# 1264  Hearst Gives Back,Hearst Television,WTAE,Proje...
# 1265  Anchors,Reporters,Derecho,Hearst Television,Na...
# 1266  Hearst Gives Back,Hearst Television,WTAE,Proje...
# 1267  Hearst Gives Back,Hearst Television,2020,KCCI,...
# 1268                  Hearst Gives Back,Field Reporters
# 1269  Hearst Television,Wildfires,Natural Disaster,K...
# 1270  Hearst Gives Back,Hearst Television,WDSU,Natur...
# 1271  Hearst Television,Natural Disasters,Weathermen...
# 1272  Hearst Gives Back,Hearst Television,KSBW,Natur...
# 1273  Hearst Television,Wildfires,Natural Disaster,K...
# 1490       Matter of Fact,Matter of Fact Listening Tour
# 1491       Matter of Fact,Matter of Fact Listening Tour
# 1561  necklace,accessories,jewelry,accessory,person,...
# 1562  person,human,female,face,clothing,apparel,smil...
# 8133                    Hearst Family,USSYP,Will Hearst
# 8134                    Hearst Family,USSYP,Will Hearst
# 8135                    Hearst Family,USSYP,Will Hearst
# 8138                    Hearst Family,USSYP,Will Hearst
# 8157                                              USSYP
# 8171               Socialites,Hearst,California,Benefit
# 8173  Hearst Castle Preservation Foundation Annual B...
# 8177                                    person,clothing
# 8180  Hearst Family,125,125th Anniversary,Citizen He...
# 8181                                      Hearst Family
#
#                                                Creators                 Date  \
# 54                                    Hearst Television                  NaN
# 55                                    Hearst Television                  NaN
# 56                                    Hearst Television                  NaN
# 57                                                  NaN                  NaN
# 58                                    Hearst Television                  NaN
# 59                                    Hearst Television                  NaN
# 60                                    Hearst Television                  NaN
# 61                                    Hearst Television                  NaN
# 62                                    Hearst Television                  NaN
# 63                                    Hearst Television                  NaN
# 66                                                  NaN                  NaN
# 1254                                  Hearst Television                  NaN
# 1255                                                NaN                  NaN
# 1256                                  Hearst Television                  NaN
# 1257                                  Hearst Television                  NaN
# 1258                                  Hearst Television                  NaN
# 1259                                        Todd\, Nate                  NaN
# 1260                                  Hearst Television                  NaN
# 1261                                  Hearst Television                  NaN
# 1262                                  Hearst Television                  NaN
# 1263                                  Hearst Television                  NaN
# 1264                                  Hearst Television                  NaN
# 1265                                  Hearst Television                  NaN
# 1266                                  Hearst Television                  NaN
# 1267                                  Hearst Television                  NaN
# 1268  Hearst Television,KCRA,Natural Disaster,Wildfires                  NaN
# 1269                                  Hearst Television                  NaN
# 1270                                  Hearst Television                  NaN
# 1271                                  Hearst Television                  NaN
# 1272                                  Hearst Television                  NaN
# 1273                                  Hearst Television                  NaN
# 1490                                                NaN                  NaN
# 1491                                                NaN                  NaN
# 1561                                                NaN                  NaN
# 1562                                                NaN                  NaN
# 8133                         Jakub Mosur and Erin Lubin  2019-03-06T12:28:32
# 8134                         Jakub Mosur and Erin Lubin  2019-03-06T12:28:35
# 8135                         Jakub Mosur and Erin Lubin  2019-03-05T14:06:52
# 8138                         Jakub Mosur and Erin Lubin  2019-03-05T12:28:58
# 8157                         Jakub Mosur and Erin Lubin  2012-03-08T18:50:38
# 8171                                                NaN                  NaN
# 8173                                   PATRICK MCMULLAN                  NaN
# 8177                                                NaN                  NaN
# 8180                                   PATRICK McMULLAN                  NaN
# 8181                                                NaN                  NaN
#
#        Washington Week  #HearstElevatorSelfie  ...  volunteering  weather  \
# 54                   0                      0  ...             0        0
# 55                   0                      0  ...             0        0
# 56                   0                      0  ...             0        0
# 57                   0                      0  ...             0        0
# 58                   0                      0  ...             0        0
# 59                   0                      0  ...             0        0
# 60                   0                      0  ...             0        0
# 61                   0                      0  ...             0        0
# 62                   0                      0  ...             0        0
# 63                   0                      0  ...             0        0
# 66                   0                      0  ...             0        0
# 1254                 0                      0  ...             0        0
# 1255                 0                      0  ...             0        0
# 1256                 0                      0  ...             0        0
# 1257                 0                      0  ...             0        0
# 1258                 0                      0  ...             0        0
# 1259                 0                      0  ...             0        0
# 1260                 0                      0  ...             0        0
# 1261                 0                      0  ...             0        0
# 1262                 0                      0  ...             0        0
# 1263                 0                      0  ...             0        0
# 1264                 0                      0  ...             0        0
# 1265                 0                      0  ...             0        0
# 1266                 0                      0  ...             0        0
# 1267                 0                      0  ...             0        0
# 1268                 0                      0  ...             0        0
# 1269                 0                      0  ...             0        0
# 1270                 0                      0  ...             0        0
# 1271                 0                      0  ...             0        0
# 1272                 0                      0  ...             0        0
# 1273                 0                      0  ...             0        0
# 1490                 0                      0  ...             0        0
# 1491                 0                      0  ...             0        0
# 1561                 0                      0  ...             0        0
# 1562                 0                      0  ...             0        0
# 8133                 0                      0  ...             0        0
# 8134                 0                      0  ...             0        0
# 8135                 0                      0  ...             0        0
# 8138                 0                      0  ...             0        0
# 8157                 0                      0  ...             0        0
# 8171                 0                      0  ...             0        0
# 8173                 0                      0  ...             0        0
# 8177                 0                      0  ...             0        0
# 8180                 0                      0  ...             0        0
# 8181                 0                      0  ...             0        0
#
#       websites  woman  women's history month  workout    Gil Maurer  \
# 54           0      0                      0        0             0
# 55           0      0                      0        0             0
# 56           0      0                      0        0             0
# 57           0      0                      0        0             0
# 58           0      0                      0        0             0
# 59           0      0                      0        0             0
# 60           0      0                      0        0             0
# 61           0      0                      0        0             0
# 62           0      0                      0        0             0
# 63           0      0                      0        0             0
# 66           0      0                      0        0             0
# 1254         0      0                      0        0             0
# 1255         0      0                      0        0             0
# 1256         0      0                      0        0             0
# 1257         0      0                      0        0             0
# 1258         0      0                      0        0             0
# 1259         0      0                      0        0             0
# 1260         0      0                      0        0             0
# 1261         0      0                      0        0             0
# 1262         0      0                      0        0             0
# 1263         0      0                      0        0             0
# 1264         0      0                      0        0             0
# 1265         0      0                      0        0             0
# 1266         0      0                      0        0             0
# 1267         0      0                      0        0             0
# 1268         0      0                      0        0             0
# 1269         0      0                      0        0             0
# 1270         0      0                      0        0             0
# 1271         0      0                      0        0             0
# 1272         0      0                      0        0             0
# 1273         0      0                      0        0             0
# 1490         0      0                      0        0             0
# 1491         0      0                      0        0             0
# 1561         0      0                      0        0             0
# 1562         0      1                      0        0             0
# 8133         0      0                      0        0             0
# 8134         0      0                      0        0             0
# 8135         0      0                      0        0             0
# 8138         0      0                      0        0             0
# 8157         0      0                      0        0             0
# 8171         0      0                      0        0             0
# 8173         0      0                      0        0             0
# 8177         0      0                      0        0             0
# 8180         0      0                      0        0             0
# 8181         0      0                      0        0             0
#
#        Headshots   People @ Work   Portraits
# 54             0               0           0
# 55             0               0           0
# 56             0               0           0
# 57             0               0           0
# 58             0               0           0
# 59             0               0           0
# 60             0               0           0
# 61             0               0           0
# 62             0               0           0
# 63             0               0           0
# 66             0               0           0
# 1254           0               0           0
# 1255           0               0           0
# 1256           0               0           0
# 1257           0               0           0
# 1258           0               0           0
# 1259           0               0           0
# 1260           0               0           0
# 1261           0               0           0
# 1262           0               0           0
# 1263           0               0           0
# 1264           0               0           0
# 1265           0               0           0
# 1266           0               0           0
# 1267           0               0           0
# 1268           0               0           0
# 1269           0               0           0
# 1270           0               0           0
# 1271           0               0           0
# 1272           0               0           0
# 1273           0               0           0
# 1490           0               0           0
# 1491           0               0           0
# 1561           0               0           0
# 1562           0               0           0
# 8133           0               0           0
# 8134           0               0           0
# 8135           0               0           0
# 8138           0               0           0
# 8157           0               0           0
# 8171           0               0           0
# 8173           0               0           0
# 8177           0               0           0
# 8180           0               0           0
# 8181           0               0           0
#
# [45 rows x 1459 columns]

# %%
#Number of features to be used in dataset for training before feature importance is taken
len(tag_list)+ metadata_df.shape[1] - 1
# Out:
# 103

# %%
image_df_original = clean_df.iloc[:,[0,1,2,3,4,6,7]]

# %%
image_df_original = image_df_original.join(clean_df[tag_list])

# %%
(tag_list)
# Out:
# ['People @ Work',
#  'Events',
#  '44th Floor',
#  'Texas',
#  'Hearst Magazines',
#  'Magazines',
#  'FAB',
#  'Frank Bennack',
#  '2019',
#  'Frank A. Bennack',
#  '2021',
#  '2016',
#  '2018',
#  'Hearst Tower',
#  'Friday',
#  'Thursday',
#  '2013',
#  'The Long Gray Line',
#  'Homecoming',
#  'Retreat',
#  'Texas 2018',
#  'Corporate',
#  'Headshots',
#  'Portraits',
#  '2017',
#  'SRS',
#  'Spotlight',
#  'Steve Swartz',
#  'Steven R. Swartz',
#  'Awards',
#  'Annual',
#  'Hearst magazines',
#  'Executives',
#  'Alfred E. Smith Memorial Foundation',
#  'Al Smith Dinner',
#  'Archdiocese of New York',
#  'Charities',
#  'Alfred E. Smith Memorial Foundation Dinner',
#  'Al Smith Dinner 2021',
#  'Catholic charities',
#  'Dinners',
#  'Texas 2016',
#  'Editorial Excellence',
#  'magazines',
#  'Texas 2017',
#  'Gil Maurer',
#  'GCM',
#  'Texas 2019',
#  'Masterclass',
#  'Gilbert C. Maurer',
#  'Annual Review',
#  'Leave Something on the Table',
#  'Spotlight 2016',
#  'Tower Gala',
#  'Photography',
#  'Hearst Real Estate',
#  'Real Estate',
#  'Tower',
#  'Tower Week',
#  'Tower Tuesdays',
#  'Joseph Urban Theater',
#  '135',
#  'Hearst Ranch',
#  'Employee Image',
#  'Ranch',
#  'FAB Book Party',
#  'Cattle',
#  'Exhibitions',
#  'Alexey Brodovitch Gallery',
#  'Career Site',
#  'Event',
#  'Annual 2019',
#  'Hearst.com',
#  'Editorial Excellence 2016',
#  'Mark Lake Bennack',
#  'Mary Lake Bennack',
#  'Michael Clinton',
#  'MAC',
#  'Michael A. Clinton',
#  'Content With Purpose',
#  'San Simeon',
#  'Outdoors',
#  'Troy Young',
#  '2014',
#  'Ventures',
#  'Hearst Ventures',
#  'HearstLab',
#  'Kate Lewis',
#  'David Carey',
#  'Colin Powell',
#  'Norman Foster',
#  'Culture Shift Labs',
#  'Hearst Health',
#  'Gathering',
#  'Horseback Riding',
#  'Ellen Levine']

# %%
#Removing Duplicate Tags/Features(found due to case sensitivity) After Setting Original Tag to 1.
print('Before Duplication Hearst Magazines:', image_df_original['Hearst Magazines'].sum())
print('Before Duplication Magazines' ,image_df_original['Magazines'].sum())
print('Hearst magazines count' , image_df_original['Hearst magazines'].sum())
print('magazines count' , image_df_original['magazines'].sum())

image_df_original.loc[image_df_original['Hearst magazines']==1,'Hearst Magazines'] = 1
image_df_original.loc[image_df_original['magazines']==1,'Magazines'] = 1

print('After Duplication handling Hearst Magazines:' ,image_df_original['Hearst Magazines'].sum())
print('After Duplication handling Magazines' ,image_df_original['Magazines'].sum())
# Out:
# Before Duplication Hearst Magazines: 1611
# Before Duplication Magazines 1494
# Hearst magazines count 532
# magazines count 456
# After Duplication handling Hearst Magazines: 1611
# After Duplication handling Magazines 1612

# %%
image_df_original.drop(labels=['Hearst magazines','magazines'], axis=1, inplace = True)
tag_list = [x for x in tag_list if x != 'Hearst magazines']
tag_list = [x for x in tag_list if x != 'magazines']

# %%
image_df_original['target'] = image_df_original.iloc[:,7:].apply(lambda row: '_'.join(row.values.astype(str)), axis=1)

# %%
df =pd.DataFrame(image_df_original[image_df_original['People @ Work']==1].iloc[:,8:].sum(axis = 0))
df.columns = ['counts']
df = df.reset_index()
df.head()
# Out:
#               index counts
# 0            Events   5896
# 1        44th Floor   2989
# 2             Texas   2075
# 3  Hearst Magazines   1531
# 4         Magazines   1531

# %%
type(df['counts'].iloc[1])
# Out:
# numpy.int64

# %%
df.sort_values(by=['counts'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-d69e7e097efa> in <module>
# ----> 1 df.sort_values(by=['counts'])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    5462                 ascending = ascending[0]
#    5463
# -> 5464             indexer = nargsort(
#    5465                 k, kind=kind, ascending=ascending, na_position=na_position, key=key
#    5466             )
#
# ~\anaconda3\lib\site-packages\pandas\core\sorting.py in nargsort(items, kind, ascending, na_position, key, mask)
#     378         non_nans = non_nans[::-1]
#     379         non_nan_idx = non_nan_idx[::-1]
# --> 380     indexer = non_nan_idx[non_nans.argsort(kind=kind)]
#     381     if not ascending:
#     382         indexer = indexer[::-1]
#
# TypeError: '>' not supported between instances of 'numpy.ndarray' and 'str'

# %%
len(image_df_original['target'].unique())

# %% [markdown]
# ## ETL For Final Dataset for Folder Creation

# %% [markdown]
# #### Write separate function or a combination of functions which follows the following steps:
# 1. Create folder for a tag in tag_list
# 2. filter images in clean_df for which contain that tag in the keyword
# 3. iterate through each file name in the clean_df. Concatenate with source parth and set it as src_dir
# 4. set destination dir as the folder created in step 1.

# %%
# #Create Directory using OS

# main_dir = "C:/Examples/Python_files/OS_module"
 
# os.makedirs(main_dir,mode = 0o666) 
# print("Directory '% s' is built!" % main_dir) 

# #copy image from one folder to another in python
# src_dir = "your/source/dir"
# dst_dir = "your/destination/dir"
# for jpgfile in glob.iglob(os.path.join(src_dir, "*.jpg")):
#     shutil.copy(jpgfile, dst_dir)

# %% [markdown]
# ##### Step 1 : Defining a function to Create a Folder for a tag list.

# %%
def create_dir(image_df,tag_list):

## create folders
    for i in tag_list:
        main_dir = "C:/Users/abhij/Hearst/Train_Images/"+str(i)

        os.makedirs(main_dir,mode = 0o666) 
        print("Directory '% s' is built!" % main_dir) 

## filter dataframe on current tag to obtain image file list
        file_name_list = list(image_df_original[image_df_original[i]==1]['File Name'])
    
## iterate through the file name list to set source and destination path based on current tag and copy from source to destination
        for i in file_name_list:
            src_dir = "C:/Users/abhij/Hearst/images/"+str(i)
            shutil.copy(src_dir, main_dir)

# %% [markdown]
# ##### Step 2 : filter images in clean_df for which contain that tag in the keyword

# %%
file_name_list = list(image_df_original[image_df_original[tag_list[0]]==1]['Record ID'].str.)

# %%
file_name_list

# %%
# src_dir = "C:/Users/abhij/images/"+str(file_name_list[0])+".jpg"
# dest_dir = "C:/Users/abhij"
# #shutil.copy(src_dir,dest_dir)

# %%
image_df_original
