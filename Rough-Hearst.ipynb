# %%
import pandas as pd
import numpy as np

# %%
metadata_df = pd.read_csv("Image_Data/metadata.csv")

# %%
metadata_df.head(15)
# Out:
#     Record ID                                          File Name  \
# 0   207431327         HearstTransportation_CAMP_MontrealTeam.png
# 1   207431332  HearstTransportation_MicrosoftTeams_ZoomMeetin...
# 2   207431348   HearstTransportation_BlackBook_LauraWehunt_1.png
# 3   207431356   HearstTransportation_BlackBook_LauraWehunt_2.png
# 4   207432753                   HearstMagazines_CDS_Employee.png
# 5   207432784                HearstMagazines_Affinity Groups.png
# 6   207432786      HearstMagazines_Value_WeEvolveWithPurpose.png
# 7   207432788         HearstMagazines_Value_hearst_galleries.png
# 8   207432796              HearstMagazines_CommunityOutreach.png
# 9   207432797     HearstMagazines_HR_Good HousekeepingOffice.png
# 10  207432881                   HearstHealth_FDB_OneWarmCoat.png
# 11  207432894                    HearstHealth_FDB_GivesBack3.png
# 12  207432937                         HearstHealth_Executive.png
# ...

# %%
metadata_df.groupby(by = ['Keywords']).agg('count').sort_values(by = ['Record ID'], ascending=False)
# Out:
#                                                     Record ID  File Name  \
# Keywords
# People @ Work,Homecoming,2013,Events,44th Floor...        443        443
# People @ Work,2018,Events,Friday,Texas,Texas 20...        258        258
# Archdiocese of New York,Corporate,Al Smith Dinn...        230        230
# People @ Work,Spotlight 2016,Awards,Hearst Maga...        140        140
# People @ Work,Frank A. Bennack,Frank Bennack,Ev...        127        127
# ...                                                       ...        ...
# HearstLab Scouts,Clemente,Michelle Clemente,Hea...          1          1
# Hearst.com,Tiles,Headshots,Philips,1276x960,Por...          1          1
# Hearst.com,Tiles,Headshots,Neal,1276x960,Portra...          1          1
# Hearst.com,Headshots,Rob Barrett,Hearst Newspap...          1          1
#  Portraits,THE CLUB,Headshots,Portraits,2020                1          1
#
#                                                     Assignment ID  Year  \
# ...

# %% [markdown]
# #### Split on comma and find individual keywords

# %%
clean_df = metadata_df.copy()

# %%
#Defining a dictionary 
keyword_dict = {}

split_df = clean_df['Keywords'].str.split(',',expand = True)
split_df
# Out:
#                     0                      1                 2   \
# 0        People @ Work  Hearst transportation    Transportation
# 1        People @ Work  Hearst transportation    Transportation
# 2        People @ Work  Hearst transportation         Headshots
# 3        People @ Work  Hearst transportation         Headshots
# 4        People @ Work                    CDS  Hearst Magazines
# ...                ...                    ...               ...
# 9294  Steven R. Swartz           Steve Swartz               SRS
# 9295  Steven R. Swartz           Steve Swartz               SRS
# 9296  Steven R. Swartz           Steve Swartz               SRS
# 9297  Steven R. Swartz           Steve Swartz               125
# 9298  Steven R. Swartz           Steve Swartz               SRS
#
#                     3               4                      5               6   \
# 0       Employee Image            CAMP  Hearst Transportation     Career Site
# ...

# %%
split_df.values
# Out:
# array([['People @ Work', 'Hearst transportation', 'Transportation', ...,
#         None, None, None],
#        ['People @ Work', 'Hearst transportation', 'Transportation', ...,
#         None, None, None],
#        ['People @ Work', 'Hearst transportation', 'Headshots', ..., None,
#         None, None],
#        ...,
#        ['Steven R. Swartz', 'Steve Swartz', 'SRS', ..., None, None, None],
#        ['Steven R. Swartz', 'Steve Swartz', '125', ..., None, None, None],
#        ['Steven R. Swartz', 'Steve Swartz', 'SRS', ..., None, None, None]],
#       dtype=object)

# %%
id_df = pd.read_csv("Image_Data/ids.csv")

# %%
id_df = id_df.iloc[:,:2]

# %%
id_df[id_df['record_id'] == 207386272]
# Out:
#       record_id                    file_name
# 8175  207386272  Miller_cropped_PMC_3098.jpg

# %%
df

# %%
### Further steps
